# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.DataFrame([11,25,254,545],columns=["col_nam"])

# %%
df=pd.DataFrame([11,25,254,545],columns=["Col_nam"])
print(df)
# Out:
#    Col_nam
# 0       11
# 1       25
# 2      254
# 3      545

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data ={
    'Name': ["naveen", "omkar","vikas","om"],
    'Age': [45,25,55,21],
    'Salary': [25000,23555,56110,45000],
    'ID': [101,201,301,401]
}

# %%
df= pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary   ID
# 0  naveen   45   25000  101
# 1   omkar   25   23555  201
# 2   vikas   55   56110  301
# 3      om   21   45000  401

# %%
df
# Out:
#      Name  Age  Salary
# 0  naveen   45   25000
# 1   omkar   25   23555
# 2   vikas   55   56110
# 3      om   21   45000

# %%
df.head(3)
# Out:
#      Name  Age  Salary
# 0  naveen   45   25000
# 1   omkar   25   23555
# 2   vikas   55   56110

# %%
df.head(1)
# Out:
#      Name  Age  Salary
# 0  naveen   45   25000

# %%
df.tail(2)
# Out:
#     Name  Age  Salary
# 2  vikas   55   56110
# 3     om   21   45000

# %%
df.tail(1)
# Out:
#   Name  Age  Salary
# 3   om   21   45000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df
# Out:
#      Name  Age  Salary
# 0  naveen   45   25000
# 1   omkar   25   23555
# 2   vikas   55   56110
# 3      om   21   45000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   36.500000  37416.250000
# std    16.196707  15845.788807
# min    21.000000  23555.000000
# 25%    24.000000  24638.750000
# 50%    35.000000  35000.000000
# 75%    47.500000  47777.500000
# max    55.000000  56110.000000

# %%
df
# Out:
#      Name  Age  Salary   ID
# 0  naveen   45   25000  101
# 1   omkar   25   23555  201
# 2   vikas   55   56110  301
# 3      om   21   45000  401
