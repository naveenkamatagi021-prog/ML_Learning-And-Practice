# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cols=["tname","hname","lname","rname","yname","uname","iname","oname","pname","sname","xname","vname","bname","nname","mname","zname","aname","aname","jname"]

dataset=pd.read_excel(r'C:\Users\Naveen s kamatagi\Downloads\4-hour-course-xl-files\07.sample-data-excel-portfolio-project.xlsx',names=cols)
dataset.head()
dataset.head()
# Out:
#            tname        hname     lname           rname                yname  \
# NaN          NaN          NaN       NaN             NaN                  NaN
# NaN  Call number  Customer ID  Duration  Representative         Date of Call
# NaN    Call_7271        C0003       116             R05  2023-01-01 00:00:00
# NaN    Call_7272        C0004       119             R05  2023-01-01 00:00:00
# NaN    Call_7273        C0005        68             R02  2023-01-01 00:00:00
#
#                uname                iname oname        pname            sname  \
# NaN              NaN                  NaN   NaN          NaN              NaN
# NaN  Purchase Amount  Satisfaction Rating    FY  Day of week  Duration Bucket
# NaN              128                  4.9  2023       Sunday     1 to 2 hours
# NaN              135                  2.9  2023       Sunday     1 to 2 hours
# NaN               66                  4.7  2023       Sunday     1 to 2 hours
#
# ...

# %%
dataset.shape
# Out:
# (1002, 19)

# %%
dataset.isnull()
# Out:
#      tname  hname  lname  rname  yname  uname  iname  oname  pname  sname  \
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN  False  False  False  False  False  False  False  False  False  False
#
#      xname  vname  bname  nname  mname  zname  aname  aname.1  jname
# ...

# %%
dataset.isnull().sum()
# Out:
# tname         1
# hname         1
# lname         1
# rname         1
# yname         1
# uname         1
# iname         1
# oname         1
# pname         1
# sname         1
# xname         1
# vname      1002
# bname      1002
# nname      1002
# mname      1002
# zname       986
# aname       986
# aname.1     986
# jname       986
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(7963)

# %%
dataset.notnull()
# Out:
#      tname  hname  lname  rname  yname  uname  iname  oname  pname  sname  \
# NaN  False  False  False  False  False  False  False  False  False  False
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
# NaN   True   True   True   True   True   True   True   True   True   True
#
#      xname  vname  bname  nname  mname  zname  aname  aname.1  jname
# ...

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(11075)

# %%
(dataset.isnull().sum().sum())*100
# Out:
# np.int64(796300)

# %%
dataset.shape[0]
# Out:
# 1002

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# tname        0.099800
# hname        0.099800
# lname        0.099800
# rname        0.099800
# yname        0.099800
# uname        0.099800
# iname        0.099800
# oname        0.099800
# pname        0.099800
# sname        0.099800
# xname        0.099800
# vname      100.000000
# bname      100.000000
# nname      100.000000
# mname      100.000000
# zname       98.403194
# aname       98.403194
# aname.1     98.403194
# jname       98.403194
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(41.82687257064818)

# %%
sns.heatmap(dataset.isnull())
plt.show()
