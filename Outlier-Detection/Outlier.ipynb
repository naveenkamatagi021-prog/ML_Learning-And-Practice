# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\Naveen s kamatagi\Downloads\4-hour-course-xl-files\Loan payments data.csv',encoding='latin1')

# %%
dataset.head(4)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male

# %%
dataset.shape
# Out:
# (500, 11)

# %%
dataset.describe()
# Out:
#          Principal       terms  past_due_days         age
# count   500.000000  500.000000      200.00000  500.000000
# mean    943.200000   22.824000       36.01000   31.116000
# std     115.240274    8.000064       29.38088    6.084784
# min     300.000000    7.000000        1.00000   18.000000
# 25%    1000.000000   15.000000        3.00000   27.000000
# 50%    1000.000000   30.000000       37.00000   30.000000
# 75%    1000.000000   30.000000       60.00000   35.000000
# max    1000.000000   30.000000       76.00000   51.000000

# %%
sns.boxplot(x='Principal',data=dataset)
plt.show()

# %%
sns.boxplot(x='age',data=dataset)
plt.show()

# %%
sns.histplot(dataset["Principal"],kde=True)
plt.show()

# %%
sns.histplot(dataset["age"],kde=True)
plt.show()

# %%
q1=dataset['age'].quantile(0.25)
q3=dataset['age'].quantile(0.75)
q3
# Out:
# np.float64(35.0)

# %%
IQR=q3-q1

# %%
min_range=q1-(1.5*IQR)
max_range=q3-(1.5*IQR)
min_range,max_range
# Out:
# (np.float64(15.0), np.float64(23.0))

# %%
new_dataset=dataset[dataset["age"]<=max_range]
new_dataset.shape
# Out:
# (32, 11)

# %%
sns.boxplot(x='age',data=new_dataset)
plt.show()

# %%
sns.histplot(new_dataset["age"],kde=True)
plt.show()

# %%
datasets=pd.read_csv(r'C:\Users\Naveen s kamatagi\Downloads\4-hour-course-xl-files\Loan payments data.csv',encoding='latin1')

# %%
datasets.shape
# Out:
# (500, 12)

# %%
datasets.head(3)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
#
#      paid_off_time  past_due_days  age             education  Gender   z_score
# 0  9/14/2016 19:31            NaN   45  High School or Below    male  2.281757
# 1   10/7/2016 9:00            NaN   50              Bechalor  female  3.103479
# 2  9/25/2016 16:58            NaN   33              Bechalor  female  0.309625

# %%
min_range=datasets["age"].mean()-(3*datasets["age"].std())
max_range=datasets["age"].mean()-(3*datasets["age"].std())
min_range , max_range
# Out:
# (np.float64(12.861648774131762), np.float64(12.861648774131762))

# %%
new_datasets=datasets[datasets["age"]<=max_range]
new_datasets.head(4)
# Out:
# Empty DataFrame
# Columns: [Loan_ID, loan_status, Principal, terms, effective_date, due_date, paid_off_time, past_due_days, age, education, Gender]
# Index: []

# %%
sns.boxplot(x='age',data=new_datasets)
plt.show()

# %%
z_score=(datasets["age"]-datasets["age"].mean())/(datasets["age"].std())

# %%
z_score>3
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: age, Length: 500, dtype: bool

# %%
z_score=(datasets["age"]-datasets["age"].mean())/(datasets["age"].std())

# %%
datasets["z_score"]=z_score

# %%
datasets[datasets["z_score"]<3]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# 5    xqd20160706             PAIDOFF        300      7       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
datasets[datasets["z_score"]<3].shape
# Out:
# (495, 12)
