# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("C:\\Users\\Naveen s kamatagi\\Downloads\\4-hour-course-xl-files\\IndividualDetails11.csv", encoding='latin1')

dataset.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30-01-2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02-02-2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03-02-2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02-03-2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02-03-2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14-02-2020                               Travelled from Wuhan
# 1         14-02-2020                               Travelled from Wuhan
# 2         14-02-2020                               Travelled from Wuhan
# 3         15-03-2020                      Travelled from Austria, Italy
# 4         02-03-2020  Travelled from Dubai to Bangalore on 20th Feb,...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28182 entries, 0 to 28181
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  28182 non-null  int64
#  1   government_id       2997 non-null   object
#  2   diagnosed_date      28182 non-null  object
#  3   age                 2346 non-null   object
#  4   gender              5313 non-null   object
#  5   detected_city       2350 non-null   object
#  6   detected_district   21198 non-null  object
#  7   detected_state      28182 non-null  object
#  8   nationality         2709 non-null   object
#  9   current_status      28182 non-null  object
#  10  status_change_date  27780 non-null  object
#  11  notes               26847 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.6+ MB

# %%
dataset.isnull()
# Out:
#           id  government_id  diagnosed_date    age  gender  detected_city  \
# 0      False          False           False  False   False          False
# 1      False          False           False   True    True          False
# 2      False          False           False   True    True          False
# 3      False          False           False  False   False          False
# 4      False          False           False  False   False          False
# ...      ...            ...             ...    ...     ...            ...
# 28177  False           True           False   True    True           True
# 28178  False           True           False   True    True           True
# 28179  False           True           False   True    True           True
# 28180  False           True           False   True    True           True
# 28181  False           True           False   True    True           True
#
#        detected_district  detected_state  nationality  current_status  \
# 0                  False           False        False           False
# 1                  False           False        False           False
# 2                  False           False        False           False
# 3                  False           False        False           False
# 4                  False           False        False           False
# ...                  ...             ...          ...             ...
# 28177               True           False         True           False
# 28178              False           False         True           False
# 28179               True           False         True           False
# 28180              False           False         True           False
# 28181               True           False         True           False
#
#        status_change_date  notes
# 0                   False  False
# 1                   False  False
# 2                   False  False
# 3                   False  False
# 4                   False  False
# ...                   ...    ...
# 28177                True  False
# 28178                True  False
# 28179                True  False
# 28180                True  False
# 28181                True  False
#
# [28182 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# id                        0
# government_id         25185
# diagnosed_date            0
# age                   25836
# gender                22869
# detected_city         25832
# detected_district      6984
# detected_state            0
# nationality           25473
# current_status            0
# status_change_date      402
# notes                  1335
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(133916)

# %%
dataset.shape[0]
# Out:
# 28182

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# id                     0.000000
# government_id         89.365552
# diagnosed_date         0.000000
# age                   91.675538
# gender                81.147541
# detected_city         91.661344
# detected_district     24.781776
# detected_state         0.000000
# nationality           90.387481
# current_status         0.000000
# status_change_date     1.426442
# notes                  4.737066
# dtype: float64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=['nationality'],inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#           id government_id diagnosed_date age gender  \
# 0          0      KL-TS-P1     30-01-2020  20      F
# 3          3         DL-P1     02-03-2020  45      M
# 4          4         TS-P1     02-03-2020  24      M
# 28        28         DL-P2     05-03-2020  27      M
# 33        33         TN-P1     07-03-2020  45      M
# ...      ...           ...            ...  ..    ...
# 24902  24903       KA-P494     25-04-2020  20      M
# 24903  24904       KA-P495     25-04-2020   8      M
# 24904  24905       KA-P496     25-04-2020  30      F
# 24905  24906       KA-P497     25-04-2020  50      F
# 26523  26524       KA-P501     26-04-2020  47      F
#
#                   detected_city detected_district detected_state  \
# 0                      Thrissur          Thrissur         Kerala
# 3      East Delhi (Mayur Vihar)        East Delhi          Delhi
# 4                     Hyderabad         Hyderabad      Telangana
# 28                    Janakpuri  South West Delhi          Delhi
# 33                 Kancheepuram      Kancheepuram     Tamil Nadu
# ...                         ...               ...            ...
# 24902              Hirebagewadi          Belagavi      Karnataka
# 24903              Hirebagewadi          Belagavi      Karnataka
# 24904              Hirebagewadi          Belagavi      Karnataka
# 24905                Nanjangudu            Mysuru      Karnataka
# 26523             Panemangalore  Dakshina Kannada      Karnataka
#
#       current_status status_change_date  \
# 0          Recovered         14-02-2020
# 3          Recovered         15-03-2020
# 4          Recovered         02-03-2020
# 28      Hospitalized         05-03-2020
# 33         Recovered         07-03-2020
# ...              ...                ...
# 24902   Hospitalized         25-04-2020
# 24903   Hospitalized         25-04-2020
# 24904   Hospitalized         25-04-2020
# 24905   Hospitalized         25-04-2020
# 26523   Hospitalized         26-04-2020
#
#                                                    notes
# 0                                   Travelled from Wuhan
# 3                          Travelled from Austria, Italy
# 4      Travelled from Dubai to Bangalore on 20th Feb,...
# 28                      Travelled from Italy PayTm Emp,
# 33     Travelled from Oman to Chennai Airport on 28.0...
# ...                                                  ...
# 24902                       Secondary Contact of KA-P128
# 24903                       Secondary Contact of KA-P128
# 24904                       Secondary Contact of KA-P128
# 24905                                 Contact of KA-P382
# 26523                                 Contact of KA-P432
#
# [664 rows x 11 columns]

# %%
sns.heatmap(dataset.isnull())
plt.show()
