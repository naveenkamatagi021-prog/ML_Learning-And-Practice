# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r'C:\Users\Naveen s kamatagi\Downloads\4-hour-course-xl-files\IndividualDetails11.csv',encoding='latin1')

# %%
dataset.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30-01-2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02-02-2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03-02-2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02-03-2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02-03-2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14-02-2020                               Travelled from Wuhan
# ...

# %%
#dataset.fillna(10)

# %%
#dataset.fillna(method='bfill')

# %%
#dataset=dataset.ffill()
#dataset.head()

# %%
#dataset=dataset.bfill()
#dataset.head()

# %%
#dataset = dataset.bfill(axis=1).infer_objects(copy=False)
#dataset.head()

# %%
dataset = dataset.ffill(axis=1).infer_objects(copy=False)
dataset.head()
# Out:
#    id government_id diagnosed_date         age      gender  \
# 0   0      KL-TS-P1     30-01-2020          20           F
# 1   1      KL-AL-P1     02-02-2020  02-02-2020  02-02-2020
# 2   2      KL-KS-P1     03-02-2020  03-02-2020  03-02-2020
# 3   3         DL-P1     02-03-2020          45           M
# 4   4         TS-P1     02-03-2020          24           M
#
#               detected_city detected_district detected_state nationality  \
# 0                  Thrissur          Thrissur         Kerala       India
# 1                 Alappuzha         Alappuzha         Kerala       India
# 2                 Kasaragod         Kasaragod         Kerala       India
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       India
# 4                 Hyderabad         Hyderabad      Telangana       India
#
#   current_status status_change_date  \
# 0      Recovered         14-02-2020
# 1      Recovered         14-02-2020
# 2      Recovered         14-02-2020
# ...

# %%
dataset["gender"].mode()[0]
# Out:
# 'M'

# %%
dataset["gender"].fillna(dataset["gender"].mode()[0],inplace=True)
# Out:
# C:\Users\Naveen s kamatagi\AppData\Local\Temp\ipykernel_18340\1164877784.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["gender"].fillna(dataset["gender"].mode()[0],inplace=True)

# %%
dataset
# Out:
#           id government_id diagnosed_date         age      gender  \
# 0          0      KL-TS-P1     30-01-2020          20           F
# 1          1      KL-AL-P1     02-02-2020  02-02-2020  02-02-2020
# 2          2      KL-KS-P1     03-02-2020  03-02-2020  03-02-2020
# 3          3         DL-P1     02-03-2020          45           M
# 4          4         TS-P1     02-03-2020          24           M
# ...      ...           ...            ...         ...         ...
# 28177  28178         28178     22-04-2020  22-04-2020  22-04-2020
# 28178  28179         28179     24-04-2020  24-04-2020  24-04-2020
# 28179  28180         28180     24-04-2020  24-04-2020  24-04-2020
# 28180  28181         28181     25-04-2020  25-04-2020  25-04-2020
# 28181  28182         28182     25-04-2020  25-04-2020  25-04-2020
#
#                   detected_city detected_district detected_state  nationality  \
# 0                      Thrissur          Thrissur         Kerala        India
# ...

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# government_id         0
# diagnosed_date        0
# age                   0
# gender                0
# detected_city         0
# detected_district     0
# detected_state        0
# nationality           0
# current_status        0
# status_change_date    0
# notes                 0
# dtype: int64

# %%
dataset.select_dtypes(include="object").columns
# Out:
# Index(['government_id', 'diagnosed_date', 'age', 'gender', 'detected_city',
#        'detected_district', 'detected_state', 'nationality', 'current_status',
#        'status_change_date', 'notes'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include="object").columns:
    print(i)
# Out:
# government_id
# diagnosed_date
# age
# gender
# detected_city
# detected_district
# detected_state
# nationality
# current_status
# status_change_date
# notes

# %%
for i in dataset.select_dtypes(include="object").columns:
    dataset[i].fillna(dataset[i].mode()[0])

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
#Haandling missing value using SCIKIT_LEARN

# %%
from sklearn.impute import SimpleImputer

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28182 entries, 0 to 28181
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  28182 non-null  int64
#  1   government_id       28182 non-null  object
#  2   diagnosed_date      28182 non-null  object
#  3   age                 28182 non-null  object
#  4   gender              28182 non-null  object
#  5   detected_city       28182 non-null  object
#  6   detected_district   28182 non-null  object
#  7   detected_state      28182 non-null  object
#  8   nationality         28182 non-null  object
#  9   current_status      28182 non-null  object
#  10  status_change_date  28182 non-null  object
#  11  notes               28182 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.6+ MB

# %%
dataset.select_dtypes(include="int64").columns
# Out:
# Index(['id'], dtype='object')

# %%
si=SimpleImputer(strategy="mean")
si.fit_transform(dataset[['id']])
# Out:
# array([[0.0000e+00],
#        [1.0000e+00],
#        [2.0000e+00],
#        ...,
#        [2.8180e+04],
#        [2.8181e+04],
#        [2.8182e+04]], shape=(28182, 1))

# %%
sns.heatmap(dataset.isnull())
plt.show()
